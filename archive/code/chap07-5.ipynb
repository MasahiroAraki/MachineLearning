# %% [markdown]
# # 例題7.5

# %%
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
svc = SVC(kernel='rbf')
print(svc)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
param_grid = [
  {'C': [1, 10, 100, 1000], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1]}
 ]

# %%
clf = GridSearchCV(svc, param_grid)
clf.fit(X, y) 
print(clf.cv_results_)
# Out:
# {'mean_fit_time': array([0.00100295, 0.00067123, 0.00133602, 0.00033442, 0.00033394,
#        0.00066837, 0.00033434, 0.        , 0.        , 0.00100279,
#        0.00033418, 0.00099913, 0.        , 0.        , 0.        ,
#        0.00100279, 0.        , 0.        , 0.        , 0.00033434]), 'std_fit_time': array([4.10068143e-04, 4.74645678e-04, 4.74968840e-04, 4.72943836e-04,
#        4.72269487e-04, 4.72606701e-04, 4.72831444e-04, 0.00000000e+00,
#        0.00000000e+00, 1.94667955e-07, 4.72606661e-04, 5.00237305e-06,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.94667955e-07,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.72831444e-04]), 'mean_score_time': array([0.00016697, 0.00033156, 0.        , 0.00033307, 0.        ,
#        0.00033426, 0.        , 0.00066845, 0.00100271, 0.        ,
#        0.00033426, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.00033426, 0.        , 0.        , 0.00033426]), 'std_score_time': array([2.36134743e-04, 4.68897739e-04, 0.00000000e+00, 4.71033179e-04,
#        0.00000000e+00, 4.72719053e-04, 0.00000000e+00, 4.72662867e-04,
#        2.97360213e-07, 0.00000000e+00, 4.72719053e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.72719053e-04, 0.00000000e+00, 0.00000000e+00, 4.72719053e-04]), 'param_C': masked_array(data=[1, 1, 1, 1, 1, 10, 10, 10, 10, 10, 100, 100, 100, 100,
#                    100, 1000, 1000, 1000, 1000, 1000],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.0001, 0.001, 0.01, 0.1, 1, 0.0001, 0.001, 0.01, 0.1,
#                    1, 0.0001, 0.001, 0.01, 0.1, 1, 0.0001, 0.001, 0.01,
#                    0.1, 1],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'C': 1, 'gamma': 0.0001}, {'C': 1, 'gamma': 0.001}, {'C': 1, 'gamma': 0.01}, {'C': 1, 'gamma': 0.1}, {'C': 1, 'gamma': 1}, {'C': 10, 'gamma': 0.0001}, {'C': 10, 'gamma': 0.001}, {'C': 10, 'gamma': 0.01}, {'C': 10, 'gamma': 0.1}, {'C': 10, 'gamma': 1}, {'C': 100, 'gamma': 0.0001}, {'C': 100, 'gamma': 0.001}, {'C': 100, 'gamma': 0.01}, {'C': 100, 'gamma': 0.1}, {'C': 100, 'gamma': 1}, {'C': 1000, 'gamma': 0.0001}, {'C': 1000, 'gamma': 0.001}, {'C': 1000, 'gamma': 0.01}, {'C': 1000, 'gamma': 0.1}, {'C': 1000, 'gamma': 1}], 'split0_test_score': array([0.90196078, 0.90196078, 0.94117647, 0.98039216, 0.98039216,
#        0.90196078, 0.94117647, 0.98039216, 0.98039216, 0.98039216,
#        0.94117647, 0.98039216, 1.        , 1.        , 0.98039216,
#        0.98039216, 1.        , 1.        , 0.98039216, 0.98039216]), 'split1_test_score': array([0.90196078, 0.90196078, 0.92156863, 0.96078431, 0.94117647,
#        0.90196078, 0.92156863, 0.96078431, 0.94117647, 0.94117647,
#        0.92156863, 0.96078431, 0.96078431, 0.90196078, 0.94117647,
#        0.96078431, 0.96078431, 0.92156863, 0.90196078, 0.94117647]), 'split2_test_score': array([0.9375    , 0.9375    , 0.97916667, 0.97916667, 1.        ,
#        0.9375    , 0.97916667, 0.97916667, 1.        , 1.        ,
#        0.97916667, 0.97916667, 1.        , 1.        , 0.95833333,
#        0.97916667, 1.        , 1.        , 1.        , 0.9375    ]), 'mean_test_score': array([0.91333333, 0.91333333, 0.94666667, 0.97333333, 0.97333333,
#        0.91333333, 0.94666667, 0.97333333, 0.97333333, 0.97333333,
#        0.94666667, 0.97333333, 0.98666667, 0.96666667, 0.96      ,
#        0.97333333, 0.98666667, 0.97333333, 0.96      , 0.95333333]), 'std_test_score': array([0.0165782 , 0.0165782 , 0.02371536, 0.00902067, 0.02441472,
#        0.0165782 , 0.02371536, 0.00902067, 0.02441472, 0.02441472,
#        0.02371536, 0.00902067, 0.01857681, 0.04644204, 0.01620941,
#        0.00902067, 0.01857681, 0.03715363, 0.042411  , 0.01947849]), 'rank_test_score': array([18, 18, 15,  3,  3, 18, 15,  3,  3,  3, 15,  3,  1, 11, 12,  3,  1,
#         3, 12, 14]), 'split0_train_score': array([0.91919192, 0.91919192, 0.92929293, 0.97979798, 0.96969697,
#        0.91919192, 0.93939394, 0.96969697, 0.96969697, 0.96969697,
#        0.93939394, 0.96969697, 0.96969697, 0.97979798, 0.98989899,
#        0.96969697, 0.96969697, 0.97979798, 0.97979798, 1.        ]), 'split1_train_score': array([0.94949495, 0.94949495, 0.96969697, 0.97979798, 1.        ,
#        0.94949495, 0.96969697, 0.98989899, 1.        , 1.        ,
#        0.96969697, 0.98989899, 1.        , 1.        , 1.        ,
#        0.98989899, 1.        , 1.        , 1.        , 1.        ]), 'split2_train_score': array([0.89215686, 0.89215686, 0.91176471, 0.96078431, 0.98039216,
#        0.89215686, 0.91176471, 0.96078431, 0.97058824, 0.99019608,
#        0.91176471, 0.96078431, 0.98039216, 0.98039216, 1.        ,
#        0.96078431, 0.99019608, 0.97058824, 0.98039216, 1.        ]), 'mean_train_score': array([0.92028124, 0.92028124, 0.9369182 , 0.97346009, 0.98336304,
#        0.92028124, 0.9402852 , 0.97346009, 0.98009507, 0.98663102,
#        0.9402852 , 0.97346009, 0.98336304, 0.98673005, 0.996633  ,
#        0.97346009, 0.98663102, 0.98346207, 0.98673005, 1.        ]), 'std_train_score': array([0.02342085, 0.02342085, 0.02425758, 0.00896313, 0.01254825,
#        0.02342085, 0.02365914, 0.01218023, 0.01407961, 0.01262539,
#        0.02365914, 0.01218023, 0.01254825, 0.00938641, 0.00476166,
#        0.01218023, 0.01262539, 0.01228365, 0.00938641, 0.        ])}

# %%
re = clf.cv_results_
for params, mean_score, std_score in zip(re['params'], re['mean_test_score'], re['std_test_score']):
    print("{:.2f} (+/- {:.2f}) for {}".format(mean_score, std_score*2, params))
# Out:
# 0.91 (+/- 0.03) for {'C': 1, 'gamma': 0.0001}
# 0.91 (+/- 0.03) for {'C': 1, 'gamma': 0.001}
# 0.95 (+/- 0.05) for {'C': 1, 'gamma': 0.01}
# 0.97 (+/- 0.02) for {'C': 1, 'gamma': 0.1}
# 0.97 (+/- 0.05) for {'C': 1, 'gamma': 1}
# 0.91 (+/- 0.03) for {'C': 10, 'gamma': 0.0001}
# 0.95 (+/- 0.05) for {'C': 10, 'gamma': 0.001}
# 0.97 (+/- 0.02) for {'C': 10, 'gamma': 0.01}
# 0.97 (+/- 0.05) for {'C': 10, 'gamma': 0.1}
# 0.97 (+/- 0.05) for {'C': 10, 'gamma': 1}
# 0.95 (+/- 0.05) for {'C': 100, 'gamma': 0.0001}
# 0.97 (+/- 0.02) for {'C': 100, 'gamma': 0.001}
# 0.99 (+/- 0.04) for {'C': 100, 'gamma': 0.01}
# 0.97 (+/- 0.09) for {'C': 100, 'gamma': 0.1}
# 0.96 (+/- 0.03) for {'C': 100, 'gamma': 1}
# 0.97 (+/- 0.02) for {'C': 1000, 'gamma': 0.0001}
# 0.99 (+/- 0.04) for {'C': 1000, 'gamma': 0.001}
# 0.97 (+/- 0.07) for {'C': 1000, 'gamma': 0.01}
# 0.96 (+/- 0.08) for {'C': 1000, 'gamma': 0.1}
# 0.95 (+/- 0.04) for {'C': 1000, 'gamma': 1}
